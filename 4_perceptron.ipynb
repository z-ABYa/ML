# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
positive_points = np.array([(-2,3),(0,1),(2,-1)])
negative_points = np.array([(-2,1),(0,-1),(2,-3)])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(positive_points[:,0], positive_points[:,1], color='blue', marker='o', label='Positive')
plt.scatter(negative_points[:,0], negative_points[:,1], color='red', marker='x', label='Negative')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Initial Data Points')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
# Combine all points and labels
X = np.vstack((positive_points, negative_points))
y = np.array([1]*len(positive_points) + [-1]*len(negative_points))

# %%
X
# Out:
# array([[-2,  3],
#        [ 0,  1],
#        [ 2, -1],
#        [-2,  1],
#        [ 0, -1],
#        [ 2, -3]])

# %%
y
# Out:
# array([ 1,  1,  1, -1, -1, -1])

# %%
def perceptron(X, y, steps):
    theta = np.zeros(X.shape[1])
    theta0 = 0
    for t in range (steps):
        for i, xi in enumerate(X):
            if y[i] * (np.dot(theta, xi) + theta0) <= 0:
                theta += y[i] * xi
                theta0 += y[i]
                break
    return theta, theta0

# %%
thetaFinal, theta0Final = perceptron(X, y, 1000)
thetaFinal, theta0Final
# Out:
# (array([4., 4.]), np.int64(2))
